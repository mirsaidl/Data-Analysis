# %%
import pandas as pd
import numpy as np

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# /usr/bin/sh: 1: git: not found

# %%
df = pd.read_excel('praktikum_datasets/uybor.xlsx')
df.head()
# Out:
#                                              address    district  rooms  size  \
# 0  город Ташкент, Yunusobod район, Юнусабад 8-й к...   Yunusobod      3  57.0
# 1  город Ташкент, Yakkasaroy район, 1-й тупик Шот...  Yakkasaroy      2  52.0
# 2  город Ташкент, Chilonzor район, Чиланзар 2-й к...   Chilonzor      2  42.0
# 3  город Ташкент, Chilonzor район, Чиланзар 9-й к...   Chilonzor      3  65.0
# 4     город Ташкент, Chilonzor район, площадь Актепа   Chilonzor      3  70.0
#
#    level  max_levels  price        lat        lng
# 0      4           4  52000  41.371471  69.281049
# 1      4           5  56000  41.291115  69.261104
# 2      4           4  37000  41.280784  69.223683
# 3      1           4  49500  41.290163  69.196862
# 4      3           5  55000  41.300156  69.210831

# %%
df = pd.read_table('praktikum_datasets/Electricity_Production_By_Source.csv')
df.head()
# Out:
#   Entity,Code,Year,Electricity from coal (TWh),Electricity from gas (TWh),Electricity from hydro (TWh),Electricity from other renewables (TWh),Electricity from solar (TWh),Electricity from oil (TWh),Electricity from wind (TWh),Electricity from nuclear (TWh)
# 0       Afghanistan,AFG,2000,0,0.155,0.312,0,0,0,0,0
# 1       Afghanistan,AFG,2001,0,0.094,0.498,0,0,0,0,0
# 2       Afghanistan,AFG,2002,0,0.132,0.555,0,0,0,0,0
# 3        Afghanistan,AFG,2003,0,0.309,0.63,0,0,0,0,0
# 4       Afghanistan,AFG,2004,0,0.329,0.565,0,0,0,0,0

# %%
# Change column name
df = pd.read_csv('praktikum_datasets/world_population.csv', names=['rank', 'country', 'density', 'densityMI', 'population', 'area'], header=0)
df.head()
# Out:
#    rank    country     density   densityMI  population  area
# 0     1      Macau  21946.4667  56841.3487     658.394    30
# 1     2     Monaco  19755.5000  51166.7450      39.511     2
# 2     3  Singapore   8305.1915  21510.4461    5896.686   710
# 3     4  Hong Kong   6841.3134  17719.0017    7552.810  1104
# 4     5  Gibraltar   5616.3333  14546.3033      33.698     6

# %%
# change index to any column use index_col
df = pd.read_csv('praktikum_datasets/world_population.csv', names=['rank', 'country', 'density', 'densityMI', 'population', 'area'], header=0, index_col=0)
df.head()
# Out:
#         country     density   densityMI  population  area
# rank
# 1         Macau  21946.4667  56841.3487     658.394    30
# 2        Monaco  19755.5000  51166.7450      39.511     2
# 3     Singapore   8305.1915  21510.4461    5896.686   710
# 4     Hong Kong   6841.3134  17719.0017    7552.810  1104
# 5     Gibraltar   5616.3333  14546.3033      33.698     6

# %%
df1 = pd.read_csv('praktikum_datasets/automobile_data.csv', index_col=0)
df1
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
url = "https://github.com/anvarnarz/praktikum_datasets/blob/main/netflix.xlsx?raw=true"
pd.read_excel(url, index_col='title', nrows=20)
# n rows is excuted
# Out:
#                       rating  \
# title
# White Chicks           PG-13
# Lucky Number Slevin        R
# Grey's Anatomy         TV-14
# Prison Break           TV-14
# How I Met Your Mother  TV-PG
# Supernatural           TV-14
# Breaking Bad           TV-MA
# The Vampire Diaries    TV-14
# The Walking Dead       TV-MA
# Pretty Little Liars    TV-14
# Once Upon a Time       TV-PG
# Sherlock               TV-14
# Death Note             TV-14
# Naruto                 TV-PG
# The Hunter                 R
# Lottie Dottie Chicken   TV-Y
# Arrow                  TV-14
# Black Mirror           TV-MA
# The Originals          TV-14
# The 100                   NR
#
#                                                              ratingLevel  \
# title
# White Chicks           crude and sexual humor, language and some drug...
# Lucky Number Slevin    strong violence, sexual content and adult lang...
# Grey's Anatomy         Parents strongly cautioned. May be unsuitable ...
# ...

# %%
df[(df['country'] == 'Uzbekistan') | (df['country'] == 'South Korea')]
# Out:
#           country   density  densityMI  population    area
# rank
# 23    South Korea  511.9767  1326.0197   51305.186  100210
# 133    Uzbekistan   75.8511   196.4542   33935.763  447400

# %%
df.sort_values(by='area',ascending=False)
df
# Out:
#                country     density   densityMI  population     area
# rank
# 1                Macau  21946.4667  56841.3487     658.394       30
# 2               Monaco  19755.5000  51166.7450      39.511        2
# 3            Singapore   8305.1915  21510.4461    5896.686      710
# 4            Hong Kong   6841.3134  17719.0017    7552.810     1104
# 5            Gibraltar   5616.3333  14546.3033      33.698        6
# ...                ...         ...         ...         ...      ...
# 228            Namibia      3.1338      8.1166    2587.344   825615
# 229     Western Sahara      2.3003      5.9577     611.875   266000
# 230           Mongolia      2.1286      5.5129    3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517       3.533    12173
# 232          Greenland      0.0263      0.0680      56.877  2166086
#
# [232 rows x 5 columns]

# %%
df.describe()
# Out:
#             density     densityMI    population          area
# count    232.000000    232.000000  2.320000e+02  2.320000e+02
# mean     450.585827   1167.017293  3.394292e+04  5.864610e+05
# std     2078.591351   5383.551600  1.368881e+05  1.768617e+06
# min        0.026300      0.068000  8.000000e-01  1.000000e+00
# 25%       35.442775     91.796750  4.424710e+02  3.735250e+03
# 50%       95.418750    247.134600  5.602686e+03  8.356700e+04
# 75%      240.029700    621.676950  2.149715e+04  4.403752e+05
# max    21946.466700  56841.348700  1.444216e+06  1.709824e+07

# %%
df.head()
# Out:
#         country     density   densityMI  population  area
# rank
# 1         Macau  21946.4667  56841.3487     658.394    30
# 2        Monaco  19755.5000  51166.7450      39.511     2
# 3     Singapore   8305.1915  21510.4461    5896.686   710
# 4     Hong Kong   6841.3134  17719.0017    7552.810  1104
# 5     Gibraltar   5616.3333  14546.3033      33.698     6

# %%
df.corr()
# Out:
# <ipython-input-66-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              density  densityMI  population      area
# density     1.000000   1.000000   -0.027526 -0.062919
# densityMI   1.000000   1.000000   -0.027526 -0.062919
# population -0.027526  -0.027526    1.000000  0.455106
# area       -0.062919  -0.062919    0.455106  1.000000

# %%
df.duplicated() # df.drop_duplicates identify and drop duplicates
# Out:
# rank
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# Length: 232, dtype: bool

# %%
df.to_excel('world_pop.xlsx', index=False, columns=['country', 'density','population', 'area'])
# if you want to save without automatic index put index=False

# %%
# we can choose which columns to save too by columns

# %% [markdown]
# # HDF

# %%
hdfobj = pd.HDFStore('mydata.hd5')

# %%
hdfobj['world_info'] = df
hdfobj['car_dat'] = df1
hdfobj['world_pop'] = df.population

# %%
hdfobj.keys()
# Out:
# ['/car_dat', '/world_info', '/world_pop']

# %%
hdfobj['world_pop']
# Out:
# rank
# 1       658.394
# 2        39.511
# 3      5896.686
# 4      7552.810
# 5        33.698
#          ...
# 228    2587.344
# 229     611.875
# 230    3329.289
# 231       3.533
# 232      56.877
# Name: population, Length: 232, dtype: float64

# %%
hdfobj['car_dat'].sample(7)
# Out:
#              company body-style  wheel-base  length engine-type  \
# index
# 81        volkswagen      sedan        97.3   171.7         ohc
# 5               audi      sedan        99.8   177.3         ohc
# 35            jaguar      sedan       102.0   191.7        ohcv
# 43             mazda      sedan       104.9   175.0         ohc
# 45     mercedes-benz      wagon       110.0   190.9         ohc
# 86        volkswagen      sedan        97.3   171.7         ohc
# 10               bmw      sedan       101.2   176.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 81                four          85               27   7975.0
# 5                 five         110               19  15250.0
# 35              twelve         262               13  36000.0
# 43                four          72               31  18344.0
# 45                five         123               22  28248.0
# 86                four         100               26   9995.0
# ...

# %%
hdfobj.close()

# %%
data = df.to_hdf('world.h5', key='world')
