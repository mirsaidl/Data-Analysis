# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/international-football-results-from-1872-to-2017/goalscorers.csv
# /kaggle/input/international-football-results-from-1872-to-2017/shootouts.csv
# /kaggle/input/international-football-results-from-1872-to-2017/results.csv

# %%
df = pd.read_csv('/kaggle/input/international-football-results-from-1872-to-2017/goalscorers.csv')
df.head(20)
# Out:
#           date  home_team away_team       team                        scorer  \
# 0   1916-07-02      Chile   Uruguay    Uruguay               José Piendibene
# 1   1916-07-02      Chile   Uruguay    Uruguay              Isabelino Gradín
# 2   1916-07-02      Chile   Uruguay    Uruguay              Isabelino Gradín
# 3   1916-07-02      Chile   Uruguay    Uruguay               José Piendibene
# 4   1916-07-06  Argentina     Chile  Argentina                 Alberto Ohaco
# 5   1916-07-06  Argentina     Chile      Chile                Telésforo Báez
# 6   1916-07-06  Argentina     Chile  Argentina            Juan Domingo Brown
# 7   1916-07-06  Argentina     Chile  Argentina            Juan Domingo Brown
# 8   1916-07-06  Argentina     Chile  Argentina          Alberto Marcovecchio
# 9   1916-07-06  Argentina     Chile  Argentina                 Alberto Ohaco
# 10  1916-07-06  Argentina     Chile  Argentina          Alberto Marcovecchio
# ...

# %%
import datetime as dt

# %%
type(df.date[0]) # need to convert to datetime
# Out:
# str

# %%
df['datetypo'] = pd.to_datetime(df.date, format='%Y-%m-%d') # https://strftime.org/ in this site

# %%
df.head(10)
# Out:
#          date  home_team away_team       team                scorer  minute  \
# 0  1916-07-02      Chile   Uruguay    Uruguay       José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay    Uruguay      Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay    Uruguay      Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay    Uruguay       José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile  Argentina         Alberto Ohaco     2.0
# 5  1916-07-06  Argentina     Chile      Chile        Telésforo Báez    44.0
# 6  1916-07-06  Argentina     Chile  Argentina    Juan Domingo Brown    60.0
# 7  1916-07-06  Argentina     Chile  Argentina    Juan Domingo Brown    62.0
# 8  1916-07-06  Argentina     Chile  Argentina  Alberto Marcovecchio    67.0
# 9  1916-07-06  Argentina     Chile  Argentina         Alberto Ohaco    75.0
#
#   own_goal penalty   datetypo
# 0    False   False 1916-07-02
# 1    False   False 1916-07-02
# 2    False   False 1916-07-02
# ...

# %%
df.at[0,'datetypo'].month
# Out:
# 7

# %%
df.at[0,'datetypo'].year
# Out:
# 1916

# %%
df['datetypo'].dt.year
# Out:
# 0        1916
# 1        1916
# 2        1916
# 3        1916
# 4        1916
#          ...
# 43184    2023
# 43185    2023
# 43186    2023
# 43187    2023
# 43188    2023
# Name: datetypo, Length: 43189, dtype: int32

# %%
df23 = df[df.datetypo.dt.year == 2023]

# %%
df23[df23.scorer == 'Cristiano Ronaldo']
# Out:
#              date               home_team      away_team      team  \
# 42413  2023-03-23                Portugal  Liechtenstein  Portugal
# 42414  2023-03-23                Portugal  Liechtenstein  Portugal
# 42475  2023-03-26              Luxembourg       Portugal  Portugal
# 42478  2023-03-26              Luxembourg       Portugal  Portugal
# 42663  2023-06-20                 Iceland       Portugal  Portugal
# 42951  2023-10-13                Portugal       Slovakia  Portugal
# 42953  2023-10-13                Portugal       Slovakia  Portugal
# 43006  2023-10-16  Bosnia and Herzegovina       Portugal  Portugal
# 43007  2023-10-16  Bosnia and Herzegovina       Portugal  Portugal
# 43064  2023-11-16           Liechtenstein       Portugal  Portugal
#
#                   scorer  minute own_goal penalty   datetypo
# 42413  Cristiano Ronaldo    51.0    False    True 2023-03-23
# 42414  Cristiano Ronaldo    63.0    False   False 2023-03-23
# ...

# %%
df.drop('date', axis=1, inplace=True)

# %%
df
# Out:
#        home_team    away_team       team             scorer  minute own_goal  \
# 0          Chile      Uruguay    Uruguay    José Piendibene    44.0    False
# 1          Chile      Uruguay    Uruguay   Isabelino Gradín    55.0    False
# 2          Chile      Uruguay    Uruguay   Isabelino Gradín    70.0    False
# 3          Chile      Uruguay    Uruguay    José Piendibene    75.0    False
# 4      Argentina        Chile  Argentina      Alberto Ohaco     2.0    False
# ...          ...          ...        ...                ...     ...      ...
# 43184     Greece       France     France    Youssouf Fofana    74.0    False
# 43185     Kosovo      Belarus    Belarus  Dmitry Antilevsky    43.0    False
# 43186    Romania  Switzerland    Romania       Denis Alibec    50.0    False
# 43187      Wales       Turkey      Wales      Neco Williams     7.0    False
# 43188      Wales       Turkey     Turkey       Yusuf Yazıcı    70.0    False
#
#       penalty   datetypo
# ...

# %%
df['year'] = df.datetypo.dt.year
df
# Out:
#        home_team    away_team       team             scorer  minute own_goal  \
# 0          Chile      Uruguay    Uruguay    José Piendibene    44.0    False
# 1          Chile      Uruguay    Uruguay   Isabelino Gradín    55.0    False
# 2          Chile      Uruguay    Uruguay   Isabelino Gradín    70.0    False
# 3          Chile      Uruguay    Uruguay    José Piendibene    75.0    False
# 4      Argentina        Chile  Argentina      Alberto Ohaco     2.0    False
# ...          ...          ...        ...                ...     ...      ...
# 43184     Greece       France     France    Youssouf Fofana    74.0    False
# 43185     Kosovo      Belarus    Belarus  Dmitry Antilevsky    43.0    False
# 43186    Romania  Switzerland    Romania       Denis Alibec    50.0    False
# 43187      Wales       Turkey      Wales      Neco Williams     7.0    False
# 43188      Wales       Turkey     Turkey       Yusuf Yazıcı    70.0    False
#
#       penalty   datetypo  year
# ...

# %%
months = {1:'January', 2:'February', 3:'March', 4:'April', 5:'May', 6:'June', 7:'July', 8:'August', 9:'September', 10:'October', 11:'November',12:'December'}
df['month'] = df.datetypo.dt.month
df
# Out:
#        home_team    away_team       team             scorer  minute own_goal  \
# 0          Chile      Uruguay    Uruguay    José Piendibene    44.0    False
# 1          Chile      Uruguay    Uruguay   Isabelino Gradín    55.0    False
# 2          Chile      Uruguay    Uruguay   Isabelino Gradín    70.0    False
# 3          Chile      Uruguay    Uruguay    José Piendibene    75.0    False
# 4      Argentina        Chile  Argentina      Alberto Ohaco     2.0    False
# ...          ...          ...        ...                ...     ...      ...
# 43184     Greece       France     France    Youssouf Fofana    74.0    False
# 43185     Kosovo      Belarus    Belarus  Dmitry Antilevsky    43.0    False
# 43186    Romania  Switzerland    Romania       Denis Alibec    50.0    False
# 43187      Wales       Turkey      Wales      Neco Williams     7.0    False
# 43188      Wales       Turkey     Turkey       Yusuf Yazıcı    70.0    False
#
#       penalty   datetypo  year  month
# ...

# %%
df.month = df.month.map(months)

# %%
df.head()
# Out:
#    home_team away_team       team            scorer  minute own_goal penalty  \
# 0      Chile   Uruguay    Uruguay   José Piendibene    44.0    False   False
# 1      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0    False   False
# 2      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0    False   False
# 3      Chile   Uruguay    Uruguay   José Piendibene    75.0    False   False
# 4  Argentina     Chile  Argentina     Alberto Ohaco     2.0    False   False
#
#     datetypo  year month
# 0 1916-07-02  1916  July
# 1 1916-07-02  1916  July
# 2 1916-07-02  1916  July
# 3 1916-07-02  1916  July
# 4 1916-07-06  1916  July

# %%
df[(df.year == 2022)& (df.month == 'December')]
# Out:
#         home_team away_team        team             scorer  minute own_goal  \
# 42320      Canada   Morocco     Morocco       Hakim Ziyech     4.0    False
# 42321      Canada   Morocco     Morocco  Youssef En-Nesyri    23.0    False
# 42322      Canada   Morocco      Canada       Nayef Aguerd    40.0     True
# 42323  Costa Rica   Germany     Germany       Serge Gnabry    10.0    False
# 42324  Costa Rica   Germany  Costa Rica     Yeltsin Tejeda    58.0    False
# ...           ...       ...         ...                ...     ...      ...
# 42390   Argentina    France   Argentina     Ángel Di María    36.0    False
# 42391   Argentina    France      France      Kylian Mbappé    80.0    False
# 42392   Argentina    France      France      Kylian Mbappé    81.0    False
# 42393   Argentina    France   Argentina       Lionel Messi   109.0    False
# 42394   Argentina    France      France      Kylian Mbappé   118.0    False
#
#       penalty   datetypo  year     month
# ...

# %%
leo = df[df.scorer == 'Lionel Messi']
cr7 = df[df.scorer == 'Cristiano Ronaldo']
print(len(cr7))
print(len(leo))
# Out:
# 111
# 54
