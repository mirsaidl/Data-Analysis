# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# ### PANDAS. Yakuniy vazifa. **1-QISM**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population.csv", index_col=0)

# %% [markdown]
# ### 1-VAZIFA. Yuqoridagi DF ustunlari nomini quyidagi qiymatlarga o'zgartiring va DF yuqorisidan 3 ta davlatni chiqaring
# `['davlat','zichlik_km','zichlik_mi','aholi','maydoni']`

# %%
# JAVOBNI SHUYERGA YOZING
df.columns =  ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df
# Out:
#                 davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1                Macau  21946.4667  56841.3487   658.394       30
# 2               Monaco  19755.5000  51166.7450    39.511        2
# 3            Singapore   8305.1915  21510.4461  5896.686      710
# 4            Hong Kong   6841.3134  17719.0017  7552.810     1104
# 5            Gibraltar   5616.3333  14546.3033    33.698        6
# ...                ...         ...         ...       ...      ...
# 228            Namibia      3.1338      8.1166  2587.344   825615
# 229     Western Sahara      2.3003      5.9577   611.875   266000
# 230           Mongolia      2.1286      5.5129  3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517     3.533    12173
# 232          Greenland      0.0263      0.0680    56.877  2166086
#
# [232 rows x 5 columns]

# %%
#@title To'g'ri javob
df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df.head(3)
# Out:
#          davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1         Macau  21946.4667  56841.3487   658.394       30
# 2        Monaco  19755.5000  51166.7450    39.511        2
# 3     Singapore   8305.1915  21510.4461  5896.686      710

# %% [markdown]
# ## Yuqoridagi jadval dunyo davlatlarining aholi zichligi bo'yicha reytingini ko'rsatadi.
# DF indeksi sifatida davlatning zichlik reytingi olingan (aholi eng zich yashaydigan davlatlar yuqorida).
#
# **Ustunlar:**
#
# `davlat` - Davlat nomi
#
# `zichlik_km` - har 1 kv.km. ga to'g'ri keluvchi aholi soni
#
# `zichlik_mi` - har 1 kv.milyaga to'g'ri keluvchi aholi soni (milya - AQSh masofa o'lchov birligi)
#
# `aholi` - 2021-yilga ko'rsa aholi soni (ming)
#
# `maydoni` - davlat maydoni (kv.km)

# %%
df['rating'] = df['zichlik_km'].rank()
df.sort_values(by=['zichlik_km','zichlik_mi'], ascending=False)
# Out:
#                 davlat  zichlik_km  zichlik_mi     aholi  maydoni  rating
# rank
# 1                Macau  21946.4667  56841.3487   658.394       30   232.0
# 2               Monaco  19755.5000  51166.7450    39.511        2   231.0
# 3            Singapore   8305.1915  21510.4461  5896.686      710   230.0
# 4            Hong Kong   6841.3134  17719.0017  7552.810     1104   229.0
# 5            Gibraltar   5616.3333  14546.3033    33.698        6   228.0
# ...                ...         ...         ...       ...      ...     ...
# 228            Namibia      3.1338      8.1166  2587.344   825615     5.0
# 229     Western Sahara      2.3003      5.9577   611.875   266000     4.0
# 230           Mongolia      2.1286      5.5129  3329.289  1564110     3.0
# 231   Falkland Islands      0.2902      0.7517     3.533    12173     2.0
# 232          Greenland      0.0263      0.0680    56.877  2166086     1.0
#
# [232 rows x 6 columns]

# %% [markdown]
# ### 2-VAZIFA. DF oxiridan 10 ta qator chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df.tail(10)
# Out:
#                 davlat  zichlik_km  zichlik_mi      aholi  maydoni  rating
# rank
# 223             Guyana      3.6765      9.5220    790.326   214969    10.0
# 224      French Guiana      3.6685      9.5015    306.448    83534     9.0
# 225           Suriname      3.6125      9.3564    591.800   163820     8.0
# 226          Australia      3.3526      8.6832  25788.215  7692024     7.0
# 227            Iceland      3.3335      8.6338    343.353   103000     6.0
# 228            Namibia      3.1338      8.1166   2587.344   825615     5.0
# 229     Western Sahara      2.3003      5.9577    611.875   266000     4.0
# 230           Mongolia      2.1286      5.5129   3329.289  1564110     3.0
# 231   Falkland Islands      0.2902      0.7517      3.533    12173     2.0
# 232          Greenland      0.0263      0.0680     56.877  2166086     1.0

# %% [markdown]
# ### 3-VAZIFA. DF dan 10, 20, 100, 200-indekslarda turgan davlatlarni alohida DF ko'rinishida chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df1 = pd.DataFrame([df.iloc[10],df.iloc[20],df.iloc[100],df.iloc[200]])
df1
# Out:
#          davlat  zichlik_km  zichlik_mi       aholi  maydoni  rating
# 11   Bangladesh   1126.9465   2918.7915  166303.498   147570   222.0
# 21   San Marino    557.6557   1444.3284      34.017       61   212.0
# 101       Benin    110.5560    286.3401   12451.040   112622   132.0
# 201    Paraguay     17.7495     45.9712    7219.638   406752    32.0

# %% [markdown]
# ### 4-VAZIFA. Davlatlar orasida `Uzbekistan`, `Hong-Kong`, `Antartica` borligini tekshiring

# %%
# JAVOBNI SHUYERGA YOZING
countries = ['Uzbekistan', 'Hong Kong', 'Antartica']
df[df.davlat.isin(countries)]
# Out:
#           davlat  zichlik_km  zichlik_mi      aholi  maydoni  rating
# rank
# 4      Hong Kong   6841.3134  17719.0017   7552.810     1104   229.0
# 133   Uzbekistan     75.8511    196.4542  33935.763   447400   100.0

# %% [markdown]
# ### 5-VAZIFA.
# #### 5.1 DFning `davlat` nomli ustunini uning indeksi qilib belgilang.
# #### 5.2 `davlat` ustunini tashlab yuboring.
# #### 5.3 DFni davlat nomi bo'yicha tartiblang

# %%
# JAVOBNI SHUYERGA YOZING
df.index = df.davlat
df = df.drop('davlat', axis=1)
df
# Out:
#                   zichlik_km  zichlik_mi     aholi  maydoni  rating
# davlat
# Macau             21946.4667  56841.3487   658.394       30   232.0
# Monaco            19755.5000  51166.7450    39.511        2   231.0
# Singapore          8305.1915  21510.4461  5896.686      710   230.0
# Hong Kong          6841.3134  17719.0017  7552.810     1104   229.0
# Gibraltar          5616.3333  14546.3033    33.698        6   228.0
# ...                      ...         ...       ...      ...     ...
# Namibia               3.1338      8.1166  2587.344   825615     5.0
# Western Sahara        2.3003      5.9577   611.875   266000     4.0
# Mongolia              2.1286      5.5129  3329.289  1564110     3.0
# Falkland Islands      0.2902      0.7517     3.533    12173     2.0
# Greenland             0.0263      0.0680    56.877  2166086     1.0
#
# [232 rows x 5 columns]

# %%
#@title Kutilayotgan natija
df.sort_index()
# Out:
#                    zichlik_km  zichlik_mi      aholi  maydoni  rating
# davlat
# Afghanistan           61.0757    158.1862  39835.428   652230    84.0
# Albania               99.9351    258.8318   2872.933    28748   122.0
# Algeria               18.7328     48.5179  44616.624  2381741    35.0
# American Samoa       276.8844    717.1307     55.100      199   183.0
# Andorra              165.2885    428.0971     77.355      468   155.0
# ...                       ...         ...        ...      ...     ...
# Wallis and Futuna     78.1268    202.3483     11.094      142   102.0
# Western Sahara         2.3003      5.9577    611.875   266000     4.0
# Yemen                 57.7509    149.5749  30490.640   527968    82.0
# Zambia                25.1400     65.1125  18920.651   752612    45.0
# Zimbabwe              38.6229    100.0333  15092.171   390757    60.0
#
# [232 rows x 5 columns]

# %% [markdown]
# ### 6-VAZIFA. DF dan `Uzbekistan`, `Malaysia`, `South Korea`, `France` davlatlari `aholi` va `maydoni` ustunlari bilan alohida DF ko'rinishida ajratib oling.

# %%
# JAVOBNI SHUYERGA YOZING
df2 = df.loc[['Uzbekistan', 'Malaysia', 'South Korea', 'France'], ['aholi', 'maydoni'] ]
df2
# Out:
#                  aholi  maydoni
# davlat
# Uzbekistan   33935.763   447400
# Malaysia     32776.194   330803
# South Korea  51305.186   100210
# France       65426.179   551695

# %%
#@title O'xshash natija (boshqa davlatlar uchun)
# Out:
#                  aholi  maydoni
# davlat
# Singapore     5896.686      710
# North Korea  25887.041   120538
# Germany      83900.473   357114
# Kazakhstan   18994.962  2724900

# %% [markdown]
# ### 7-VAZIFA. Asl DFning `aholi` ustuni qiymatlarini 1000 ga ko'paytiring.

# %%
# JAVOBNI SHUYERGA YOZING
df.aholi *= 1000
df
# Out:
#                    zichlik_km  zichlik_mi       aholi  maydoni  rating
# davlat
# Afghanistan           61.0757    158.1862  39835428.0   652230    84.0
# Albania               99.9351    258.8318   2872933.0    28748   122.0
# Algeria               18.7328     48.5179  44616624.0  2381741    35.0
# American Samoa       276.8844    717.1307     55100.0      199   183.0
# Andorra              165.2885    428.0971     77355.0      468   155.0
# ...                       ...         ...         ...      ...     ...
# Wallis and Futuna     78.1268    202.3483     11094.0      142   102.0
# Western Sahara         2.3003      5.9577    611875.0   266000     4.0
# Yemen                 57.7509    149.5749  30490640.0   527968    82.0
# Zambia                25.1400     65.1125  18920651.0   752612    45.0
# Zimbabwe              38.6229    100.0333  15092171.0   390757    60.0
#
# [232 rows x 5 columns]

# %%
#@title Kutilgan natija
# Out:
#                 zichlik_km  zichlik_mi       aholi  maydoni
# davlat
# Afghanistan        61.0757    158.1862  39835428.0   652230
# Albania            99.9351    258.8318   2872933.0    28748
# Algeria            18.7328     48.5179  44616624.0  2381741
# American Samoa    276.8844    717.1307     55100.0      199
# Andorra           165.2885    428.0971     77355.0      468

# %% [markdown]
# DF ni `aholi` ustuni bo'yicha kamayish tartibida tahlang va aholisi eng kam 10 ta davlatni chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df.sort_values('aholi', ascending=False)
# Out:
#                   zichlik_km  zichlik_mi         aholi  maydoni  rating
# davlat
# China               148.7815    385.3441  1.444216e+09  9706961   151.0
# India               423.8391   1097.7432  1.393409e+09  3287590   204.0
# United States        35.5200     91.9968  3.329151e+08  9372610    59.0
# Indonesia           145.1046    375.8210  2.763618e+08  1904569   150.0
# Pakistan            255.3542    661.3674  2.251999e+08   881912   180.0
# ...                      ...         ...           ...      ...     ...
# Montserrat           48.7941    126.3768  4.977000e+03      102    72.0
# Falkland Islands      0.2902      0.7517  3.533000e+03    12173     2.0
# Niue                  6.2269     16.1277  1.619000e+03      260    15.0
# Tokelau             114.4167    296.3392  1.373000e+03       12   135.0
# Vatican City        800.0000   2072.0000  8.000000e+02        1   220.0
#
# [232 rows x 5 columns]

# %% [markdown]
# ### 8-VAZIFA. DFni `maydoni` bo'yicha reytinglang (rank) va reytinglarni yangi `rank` ustuniga yozing.

# %%
# JAVOBNI SHUYERGA YOZING
df['rating'] = df.maydoni.rank()
df
# Out:
#                    zichlik_km  zichlik_mi       aholi  maydoni  rating
# davlat
# Afghanistan           61.0757    158.1862  39835428.0   652230   192.0
# Albania               99.9351    258.8318   2872933.0    28748    89.0
# Algeria               18.7328     48.5179  44616624.0  2381741   223.0
# American Samoa       276.8844    717.1307     55100.0      199    20.0
# Andorra              165.2885    428.0971     77355.0      468    38.0
# ...                       ...         ...         ...      ...     ...
# Wallis and Futuna     78.1268    202.3483     11094.0      142    15.0
# Western Sahara         2.3003      5.9577    611875.0   266000   155.0
# Yemen                 57.7509    149.5749  30490640.0   527968   183.0
# Zambia                25.1400     65.1125  18920651.0   752612   194.0
# Zimbabwe              38.6229    100.0333  15092171.0   390757   172.0
#
# [232 rows x 5 columns]

# %%
#@title Kutilgan natija
# Out:
#                    zichlik_km  zichlik_mi       aholi  maydoni   rank
# davlat
# Afghanistan           61.0757    158.1862  39835428.0   652230  192.0
# Albania               99.9351    258.8318   2872933.0    28748   89.0
# Algeria               18.7328     48.5179  44616624.0  2381741  223.0
# American Samoa       276.8844    717.1307     55100.0      199   20.0
# Andorra              165.2885    428.0971     77355.0      468   38.0
# ...                       ...         ...         ...      ...    ...
# Wallis and Futuna     78.1268    202.3483     11094.0      142   15.0
# Western Sahara         2.3003      5.9577    611875.0   266000  155.0
# Yemen                 57.7509    149.5749  30490640.0   527968  183.0
# Zambia                25.1400     65.1125  18920651.0   752612  194.0
# Zimbabwe              38.6229    100.0333  15092171.0   390757  172.0
#
# [232 rows x 5 columns]

# %% [markdown]
# #### `Uzbekistan`, `United Kingdom`, `Indonesia` davlatlari alohida df ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
df.loc[['Uzbekistan', 'United Kingdom', 'Indonesia']]
# Out:
#                 zichlik_km  zichlik_mi        aholi  maydoni  rating
# davlat
# Uzbekistan         75.8511    196.4542   33935763.0   447400   176.0
# United Kingdom    280.8033    727.2805   68207116.0   242900   153.0
# Indonesia         145.1046    375.8210  276361783.0  1904569   218.0

# %%
#@title O'xshash natija (boshqa davlatlar uchun)
# Out:
#                zichlik_km  zichlik_mi        aholi  maydoni   rank
# davlat
# Turkmenistan      12.5342     32.4635    6117924.0   488100  180.0
# United States     35.5200     91.9968  332915073.0  9372610  229.0
# Vietnam          296.3927    767.6572   98168833.0   331212  166.0

# %% [markdown]
# ### 9-VAZIFA. DFni `davlat` nomi bo'yicha tartiblang.

# %%
# JAVOBNI SHUYERGA YOZING
df
# Out:
#                    zichlik_km  zichlik_mi       aholi  maydoni  rating
# davlat
# Afghanistan           61.0757    158.1862  39835428.0   652230   192.0
# Albania               99.9351    258.8318   2872933.0    28748    89.0
# Algeria               18.7328     48.5179  44616624.0  2381741   223.0
# American Samoa       276.8844    717.1307     55100.0      199    20.0
# Andorra              165.2885    428.0971     77355.0      468    38.0
# ...                       ...         ...         ...      ...     ...
# Wallis and Futuna     78.1268    202.3483     11094.0      142    15.0
# Western Sahara         2.3003      5.9577    611875.0   266000   155.0
# Yemen                 57.7509    149.5749  30490640.0   527968   183.0
# Zambia                25.1400     65.1125  18920651.0   752612   194.0
# Zimbabwe              38.6229    100.0333  15092171.0   390757   172.0
#
# [232 rows x 5 columns]

# %%
#@title Kutilgan natija
# Out:
#                 zichlik_km  zichlik_mi       aholi  maydoni   rank
# davlat
# Afghanistan        61.0757    158.1862  39835428.0   652230  192.0
# Albania            99.9351    258.8318   2872933.0    28748   89.0
# Algeria            18.7328     48.5179  44616624.0  2381741  223.0
# American Samoa    276.8844    717.1307     55100.0      199   20.0
# Andorra           165.2885    428.0971     77355.0      468   38.0

# %% [markdown]
# #### DFdan 10,50,100,200-o'rinda turgan davlatlarni alohida DF ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
# did it

# %%
#@title O'xshash natija (boshqa qatorlar uchun)
# Out:
#                               zichlik_km  zichlik_mi     aholi  maydoni  rank
# davlat
# Belize                           17.6310     45.6643  404914.0    22966  82.0
# French Polynesia                 67.8018    175.6066  282530.0     4167  60.0
# Guadeloupe                      245.7125    636.3955  400020.0     1628  53.0
# United States Virgin Islands    300.3631    777.9405  104226.0      347  29.0

# %% [markdown]
# ### 10-VAZIFA. Quyidagi davlatlarning `aholi` sonini oddiy son ko'rinishida chiqaring:
# - `Malaysia`
# - `Nigeria`
# - `Nepal`
# - `Italy`

# %%
# JAVOBNI SHUYERGA YOZING
df.loc[['Malaysia', 'Nigeria','Nepal','Italy'],['aholi']]
# Out:
#                 aholi
# davlat
# Malaysia   32776194.0
# Nigeria   211400708.0
# Nepal      29674920.0
# Italy      60367477.0

# %%
#@title o'xshash natija (`Uzbekistan` uchun)
# Out:
# 33935763.0
